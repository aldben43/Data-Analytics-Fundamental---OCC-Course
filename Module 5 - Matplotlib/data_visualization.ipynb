# %% [markdown]
# # **MATPLOTLIB**

# %% [markdown]
# ##### Install the package

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/aldrichbenedick/Library/Python/3.13/lib/python/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aldrichbenedick/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/aldrichbenedick/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Import the package

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Types of Data Visualization in Matplotlib

# %% [markdown]
# ### 1. Line Plot
#
# The line plot, a cornerstone of data visualization, excels at revealing trends over time or across different categories. It connects data points with a line, visually depicting how a value changes in relation to another variable.

# %%
# Data for number of orders per month
data = {
    "Months": ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"],
    "No. Of Orders for Jacket": [8, 10, 12, 14, 18, 20, 26, 24, 22, 14, 12, 9],
    "No. Of Orders for Summer Clothes": [25, 27, 24, 20, 15, 13, 9, 13, 14, 16, 18, 22]
}

order_per_month = pd.DataFrame(data)
order_per_month
# Out:
#    Months  No. Of Orders for Jacket  No. Of Orders for Summer Clothes
# 0     Jan                         8                                25
# 1     Feb                        10                                27
# 2     Mar                        12                                24
# 3   April                        14                                20
# 4     May                        18                                15
# 5    June                        20                                13
# 6    July                        26                                 9
# 7     Aug                        24                                13
# 8    Sept                        22                                14
# 9     Oct                        14                                16
# 10    Nov                        12                                18
# 11    Dec                         9                                22

# %%
# Control the width and height
plt.figure(figsize=(8, 6))

# linestyle: solid, dashed, dotted, dashdot
plt.plot(order_per_month["Months"], order_per_month["No. Of Orders for Jacket"], 
         marker="o", color="blue", linestyle="dashed", linewidth=2, label="No. Of Orders for Jacket")
plt.plot(order_per_month["Months"], order_per_month["No. Of Orders for Summer Clothes"], 
         marker="s", color="orange", linestyle="dashdot", linewidth=2, label="No. Of Orders for Summer Clothes")

plt.fill_between(order_per_month["Months"], order_per_month["No. Of Orders for Jacket"], color = "skyblue", alpha = 0.3, label = "No. Of Orders for Jacket" )
plt.fill_between(order_per_month["Months"], order_per_month["No. Of Orders for Summer Clothes"], color = "yellow", alpha = 0.3, label= "No. Of Orders for Summer Clothes" )

# Adding a label
plt.xlabel("Months", fontsize = 12, fontweight='bold')
plt.ylabel("No. Of Orders", fontsize = 12, fontweight='bold')

# Add a title
plt.title("No. Of Orders per Month", fontsize = 14, fontweight='bold')

# Add the legend
plt.legend(loc="center right")
# upper right, upper left, lower right, lower left
# center right, center left

# Display the lineplot
plt.show()

# %% [markdown]
# ### 2. Pie Charts
#
# Pie charts, those delightful circles sliced into wedges, are a go-to choice for visualizing proportions of a whole.  Matplotlib's pie chart functionality, accessible through the pyplot.pie() function, empowers you to represent data categories and their relative sizes in a clear and intuitive way.

# %%
# Data for spending amounts for each category
data = {
    "Categories": ['Rent', 'Food', 'Transportation', 'Savings', 'Other'],
    "Amounts": [500, 300, 200, 100, 100]
}

spending_amount_df = pd.DataFrame(data)
spending_amount_df
# Out:
#        Categories  Amounts
# 0            Rent      500
# 1            Food      300
# 2  Transportation      200
# 3         Savings      100
# 4           Other      100

# %%
explodes = [0.1, 0, 0, 0, 0]

plt.pie(spending_amount_df["Amounts"], labels=spending_amount_df["Categories"], 
        autopct='%.2f%%', colors = ["#606c38", "#e9edc9", "#fefae0", "#dda15e", "#bc6c25"],explode = explodes)

#Colors:
#1. Named Colors
#2. Hexadecimal
#3 RGB Tuples

plt.title("Budget per each Category", fontsize=14, fontweight='bold')

# bbox_to_anchor = (x, y)
plt.legend(labels=spending_amount_df["Categories"], title="Categories", loc="lower right", bbox_to_anchor =(1.5,0.5))

plt.show()

# %% [markdown]
# #### 3. Bar Charts
#
# Bar charts, the workhorses of data visualization, excel at showcasing comparisons between different categories.  Matplotlib's bar chart functionality, primarily accessed through the pyplot.bar() function, allows you to translate numerical data into a series of rectangular bars. The height of each bar corresponds to the value it represents, while the bars are positioned along a horizontal axis that typically represents the categories being compared.

# %%
# Data for student enrollment per course
# \n - create a new line
data = {
    "Course": ['Data Analytics', 'Frontend Development', 'DevOps', 'Full-Stack Development'],
    "Students": [30, 25, 32, 28]
}

students_per_course_df = pd.DataFrame(data)
students_per_course_df
# Out:
#                    Course  Students
# 0          Data Analytics        30
# 1    Frontend Development        25
# 2                  DevOps        32
# 3  Full-Stack Development        28

# %%
plt.bar(students_per_course_df["Course"],students_per_course_df ["Students"],
        color = ["#606c38", "#e9edc9", "#fefae0", "#dda15e"])

plt.xlabel("Courses", fontsize = 12, fontweight = 'bold')
plt.ylabel("Students", fontsize = 12, fontweight = 'bold')

plt.title("Students Enrolled per Course", fontsize = 14, fontweight = 'bold')

plt.xticks(rotation=45)

plt.show()
